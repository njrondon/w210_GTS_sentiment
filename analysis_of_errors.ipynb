# %%
import json
import pandas as pd
pd.set_option('display.max_colwidth', 150)

# %%
df_opener_en_test = pd.read_json("data/opener_en/test.json")
df_en_BERT_review = pd.read_json("data/preds/en_BERT_review_pred.json")
df_en_bert_large = pd.read_json("data/preds/en_bert-large-uncased_pred.json")



df_opener_es_test = pd.read_json("data/opener_es/test.json")
df_es_roberta_bne = pd.read_json("data/preds/es_roberta-large-bne_pred.json")
df_es_xlm_roberta = pd.read_json("data/preds/es_xlm-roberta-large_pred.json")

# %%
def normalize_jsons(filepath):

    with open(filepath, 'r') as json_file:
        json_data = json.load(json_file)
        df = pd.json_normalize(
            json_data,
            record_path=["opinions"],
            sep="_",
            meta=[
                ['sent_id'],
                ['text']
            ],
            errors='ignore'
        )

    df[['Source_string','Source_index']] = pd.DataFrame(df['Source'].tolist(), index = df.index)
    df[['Target_string','Target_index']] = pd.DataFrame(df['Target'].tolist(), index = df.index)
    df[['Polar_expression_string','Polar_expression_index']] = pd.DataFrame(df['Polar_expression'].tolist(), index = df.index)
    df['Implicit_holder'] = df['Source_string'].apply(lambda x: 1 if len(x) == 0 else 0)
    df['Implicit_target'] = df['Target_string'].apply(lambda x: 1 if len(x) == 0 else 0)
    df['Implicit_holder_target'] = (df['Implicit_holder'] == 1) & (df['Implicit_target'] == 1)
    df['Implicit_expression'] = df['Polar_expression_string'].apply(lambda x: 1 if len(x) == 0 else 0)
    df['Implicit_target_exclusive'] = (df['Implicit_target']==1) & (df['Implicit_holder'] == 0) & (df['Implicit_expression']==0 ) 
    df['Implicit_holder_exclusive'] = (df['Implicit_target']==0) & (df['Implicit_holder'] == 1) & (df['Implicit_expression']==0 )
    
    df['H-A-O'] = df.apply(lambda row: 1 if (row['Implicit_target'] == 0 and row['Implicit_holder'] ==0) and row['Implicit_expression'] ==0 else 0, axis=1)
    
#    df['H-A-O'] =  (df['Implicit_target']==0) & (df['Implicit_holder'] == 0) & (df['Implicit_expression']==0 )
    df['H-IA-IO'] =(df['Implicit_target']==1) & (df['Implicit_holder'] == 0) & (df['Implicit_expression']==1 )
    df['H-A-IO'] = (df['Implicit_target']==0) & (df['Implicit_holder'] == 0) & (df['Implicit_expression']==1 )
    df['H-IA-O']=  (df['Implicit_target']==1) & (df['Implicit_holder'] == 0) & (df['Implicit_expression']==0 )
    df['IH-A-O']=  (df['Implicit_target']==0) & (df['Implicit_holder'] == 1) & (df['Implicit_expression']==0 )
    df['IH-A-IO']= (df['Implicit_target']==0) & (df['Implicit_holder'] == 1) & (df['Implicit_expression']==1 )
    df['IH-IA-O']= (df['Implicit_target']==1) & (df['Implicit_holder'] == 1) & (df['Implicit_expression']==0 )
    df['IH-IA-IO']= (df['Implicit_target']==1) & (df['Implicit_holder'] == 1) & (df['Implicit_expression']==1 )


    df = df.reindex(
        columns= [
        'text',
        'sent_id',
        'Source',
        'Source_string',
        'Source_index',
        'Target',
        'Target_string',
        'Target_index',
        'Polar_expression',
        'Polar_expression_string',
        'Polar_expression_index',
        'Polarity',
        'Intensity',
        'Implicit_holder',
        'Implicit_target',
        'Implicit_holder_target',
        'Implicit_expression',
        'Implicit_target_exclusive',
        'Implicit_holder_exclusive',
        'H-A-O', 'H-IA-IO','H-A-IO','H-IA-O','IH-A-O', 'IH-A-IO', 'IH-IA-O', 'IH-IA-IO'
        ]
    )

    return df

# %%
df_opener_en_test = normalize_jsons("data/opener_en/test.json")
df_en_BERT_review = normalize_jsons("data/preds/en_BERT_review_pred.json")
df_en_bert_large = normalize_jsons("data/preds/en_bert-large-uncased_pred.json")

df_opener_es_test = normalize_jsons("data/opener_es/test.json")
df_es_roberta_bne = normalize_jsons("data/preds/es_roberta-large-bne_pred.json")
df_es_xlm_roberta = normalize_jsons("data/preds/es_xlm-roberta-large_pred.json")

# %%
df_opener_en_test.columns

# df_en.dtypes
# df_en.columns
# df_en.shape
# Out:
# Index(['text', 'sent_id', 'Source', 'Source_string', 'Source_index', 'Target',
#        'Target_string', 'Target_index', 'Polar_expression',
#        'Polar_expression_string', 'Polar_expression_index', 'Polarity',
#        'Intensity', 'Implicit_holder', 'Implicit_target',
#        'Implicit_holder_target', 'Implicit_expression',
#        'Implicit_target_exclusive', 'Implicit_holder_exclusive', 'H-A-O',
#        'H-IA-IO', 'H-A-IO', 'H-IA-O', 'IH-A-O', 'IH-A-IO', 'IH-IA-O',
#        'IH-IA-IO'],
#       dtype='object')

# %%
df_opener_en_test.head(5)
# Out:
#                                                                         text  \
# 0                                    They were there just to keep us happy .
# 1  A wonderful place to go and we are planning to return as soon as we can .
# 2  A wonderful place to go and we are planning to return as soon as we can .
# 3                                Thank you for such a wonderful experience .
# 4                                             Hotel was under construction .
#
#                                                                sent_id  \
# 0  opener_en/kaf/hotel/english00148_ddb06f1e4ab012d85f9120c394168c48-6
# 1  opener_en/kaf/hotel/english00148_ddb06f1e4ab012d85f9120c394168c48-7
# 2  opener_en/kaf/hotel/english00148_ddb06f1e4ab012d85f9120c394168c48-7
# 3  opener_en/kaf/hotel/english00148_ddb06f1e4ab012d85f9120c394168c48-8
# 4  opener_en/kaf/hotel/english00028_2a1e03a3e5d6afe2c5024926cb7ff9ab-2
#
#             Source Source_string Source_index                   Target  \
# 0  [[us], [29:31]]          [us]      [29:31]          [[They], [0:4]]
# 1         [[], []]            []           []       [[place], [12:17]]
# 2  [[we], [28:30]]          [we]      [28:30]                 [[], []]
# 3         [[], []]            []           []  [[experience], [31:41]]
# 4         [[], []]            []           []         [[Hotel], [0:5]]
#
#   Target_string Target_index                    Polar_expression  \
# 0        [They]        [0:4]  [[to keep, happy], [21:28, 32:37]]
# 1       [place]      [12:17]               [[wonderful], [2:11]]
# 2            []           []     [[planning to return], [35:53]]
# 3  [experience]      [31:41]              [[wonderful], [21:30]]
# 4       [Hotel]        [0:5]     [[under construction], [10:28]]
#
#   Polar_expression_string  ... Implicit_target_exclusive  \
# 0        [to keep, happy]  ...                     False
# 1             [wonderful]  ...                     False
# 2    [planning to return]  ...                      True
# 3             [wonderful]  ...                     False
# 4    [under construction]  ...                     False
#
#   Implicit_holder_exclusive H-A-O  H-IA-IO  H-A-IO  H-IA-O  IH-A-O  IH-A-IO  \
# 0                     False     1    False   False   False   False    False
# 1                      True     0    False   False   False    True    False
# 2                     False     0    False   False    True   False    False
# 3                      True     0    False   False   False    True    False
# 4                      True     0    False   False   False    True    False
#
#    IH-IA-O  IH-IA-IO
# 0    False     False
# 1    False     False
# 2    False     False
# 3    False     False
# 4    False     False
#
# [5 rows x 27 columns]

# %%
df_en_BERT_review.head(5)
# Out:
#                                                                         text  \
# 0                                    They were there just to keep us happy .
# 1                                    They were there just to keep us happy .
# 2  A wonderful place to go and we are planning to return as soon as we can .
# 3                                Thank you for such a wonderful experience .
# 4                                             Hotel was under construction .
#
#                                                                sent_id  \
# 0  opener_en/kaf/hotel/english00148_ddb06f1e4ab012d85f9120c394168c48-6
# 1  opener_en/kaf/hotel/english00148_ddb06f1e4ab012d85f9120c394168c48-6
# 2  opener_en/kaf/hotel/english00148_ddb06f1e4ab012d85f9120c394168c48-7
# 3  opener_en/kaf/hotel/english00148_ddb06f1e4ab012d85f9120c394168c48-8
# 4  opener_en/kaf/hotel/english00028_2a1e03a3e5d6afe2c5024926cb7ff9ab-2
#
#             Source Source_string Source_index                   Target  \
# 0  [[They], [0:4]]        [They]        [0:4]          [[They], [0:4]]
# 1  [[They], [0:4]]        [They]        [0:4]          [[They], [0:4]]
# 2  [[we], [28:30]]          [we]      [28:30]       [[place], [12:17]]
# 3         [[], []]            []           []  [[experience], [31:41]]
# 4         [[], []]            []           []         [[Hotel], [0:5]]
#
#   Target_string Target_index                 Polar_expression  \
# 0        [They]        [0:4]                [[keep], [24:28]]
# 1        [They]        [0:4]               [[happy], [32:37]]
# 2       [place]      [12:17]            [[wonderful], [2:11]]
# 3  [experience]      [31:41]    [[such a wonderful], [14:30]]
# 4       [Hotel]        [0:5]  [[under construction], [10:28]]
#
#   Polar_expression_string  ... Implicit_target_exclusive  \
# 0                  [keep]  ...                     False
# 1                 [happy]  ...                     False
# 2             [wonderful]  ...                     False
# 3      [such a wonderful]  ...                     False
# 4    [under construction]  ...                     False
#
#   Implicit_holder_exclusive  H-A-O  H-IA-IO  H-A-IO  H-IA-O  IH-A-O  IH-A-IO  \
# 0                     False      1    False   False   False   False    False
# 1                     False      1    False   False   False   False    False
# 2                     False      1    False   False   False   False    False
# 3                      True      0    False   False   False    True    False
# 4                      True      0    False   False   False    True    False
#
#    IH-IA-O  IH-IA-IO
# 0    False     False
# 1    False     False
# 2    False     False
# 3    False     False
# 4    False     False
#
# [5 rows x 27 columns]

# %% [markdown]
# # Load Highest Scoring F1 Score Predictions and Labels

# %%
df_opener_en_test = normalize_jsons("data/opener_en/test.json")
df_opener_es_test = normalize_jsons("data/opener_es/test.json")

df_es_xlm_roberta = normalize_jsons("es_xlm-roberta-large_pred.json")
df_en_roberta_largev1 = normalize_jsons("en_all-roberta-large-v1_pred.json")

# %% [markdown]
# # Set of Aspects

# %%
# Target

en_target_tokens_test = set(sum(df_opener_en_test['Target_string'].tolist(), []))
en_target_tokens_pred = set(sum(df_en_roberta_largev1['Target_string'].tolist(), []))

es_target_tokens_test = set(sum(df_opener_es_test['Target_string'].tolist(), []))
es_target_tokens_pred = set(sum(df_es_xlm_roberta['Target_string'].tolist(), []))

# Holder

en_holder_tokens_test = set(sum(df_opener_en_test['Source_string'].tolist(), []))
en_holder_tokens_pred = set(sum(df_en_roberta_largev1['Source_string'].tolist(), []))

es_holder_tokens_test = set(sum(df_opener_es_test['Source_string'].tolist(), []))
es_holder_tokens_pred = set(sum(df_es_xlm_roberta['Source_string'].tolist(), []))

# Expression

en_expression_tokens_test = set(sum(df_opener_en_test['Polar_expression_string'].tolist(), []))
en_expression_tokens_pred = set(sum(df_en_roberta_largev1['Polar_expression_string'].tolist(), []))

es_expression_tokens_test = set(sum(df_opener_es_test['Polar_expression_string'].tolist(), []))
es_expression_tokens_pred = set(sum(df_es_xlm_roberta['Polar_expression_string'].tolist(), []))


# Polarity
en_pos_test = sum(df_opener_en_test['Polarity'] == "Positive") 
en_pos_pred = sum(df_en_roberta_largev1['Polarity'] == "Positive") 
en_neg_test = sum(df_opener_en_test['Polarity'] == "Negative") 
en_neg_pred = sum(df_en_roberta_largev1['Polarity'] == "Negative") 

es_pos_test = sum(df_opener_es_test['Polarity'] == "Positive") 
es_pos_pred = sum(df_es_xlm_roberta['Polarity'] == "Positive") 
es_neg_test = sum(df_opener_es_test['Polarity'] == "Negative") 
es_neg_pred = sum(df_es_xlm_roberta['Polarity'] == "Negative")

# %% [markdown]
# ## Polarity Counts

# %%
print(en_pos_test, en_pos_pred, en_neg_test, en_neg_pred)
# Out:
# 596 589 269 257

# %%
print(es_pos_test, es_pos_pred, es_neg_test, es_neg_pred)
# Out:
# 768 603 189 142

# %% [markdown]
# ## Set Target

# %%
en_target_diff_test = en_target_tokens_test.difference(en_target_tokens_pred)
en_target_diff_pred = en_target_tokens_test.difference(en_target_tokens_pred)

print(len(en_target_diff_test),len(en_target_tokens_test), len(en_target_tokens_pred))
# Out:
# 136 396 380

# %%
en_target_diff_test
# Out:
# {'24 hr bar',
#  'A la carte restaurant steak House',
#  'A stay',
#  'All inclusive',
#  'Busdriver Peter Langhout',
#  'Coffee maker',
#  'French cuisine',
#  'He',
#  'Hotel and Villa Dievole',
#  'Kettle',
#  'Melia Grand Hermitage',
#  'Metro',
#  'Numerous shopping',
#  'One bed',
#  'Our room',
#  'Pool',
#  'RS375 off',
#  'The TV',
#  'The all inclusive',
#  'The house · keeping',
#  'The technology provided',
#  'This',
#  'This B & amp ; B',
#  'Tuscan location',
#  'Wellness offer and quality',
#  'Wi · Fi in the room',
#  'a choice',
#  'a hotel',
#  'a hotel with such staff',
#  'a rubber duck',
#  'a waiter on hand',
#  'access to the city and Messe',
#  'all Steigenburger hotels',
#  'all rounder',
#  'anything to complain about',
#  'back massage',
#  'bars',
#  'bath',
#  'bathroom door',
#  'caffees',
#  'chairs / tables',
#  'check in',
#  'chill out',
#  'choice of drinks',
#  'cocktails',
#  'cocktails.',
#  'complex',
#  'curtains',
#  'customer',
#  'distance from firenze',
#  'dvd player',
#  'electrical outlet',
#  'enough seats',
#  'ever.staff',
#  'everything else',
#  'fitnes',
#  'foot · paths',
#  'forks',
#  'fridge in 1 of the rooms',
#  'garden',
#  'glasses',
#  'guys',
#  'hot water',
#  'internet',
#  'italian',
#  'key station',
#  'live show',
#  'my 3 · night stay',
#  'my next stay',
#  'nothing to complain',
#  'offer',
#  'people.',
#  'playground',
#  'programme',
#  'public transportation',
#  'radio',
#  'range',
#  'reason to eat in',
#  'relax time',
#  'repair',
#  'room lock',
#  'room.staff',
#  'sea',
#  'sea.very',
#  'selection for the buffet',
#  'shower',
#  'size',
#  'size of the room',
#  'skype',
#  'some aircraft noise',
#  'some of them',
#  'some rennovation',
#  'spa',
#  'speed',
#  'staff.The',
#  'sunbeds',
#  'swimming pool water',
#  'swimmingpool',
#  'tea / coffee',
#  'terrace',
#  'that place.',
#  'the 4 stars',
#  'the Metro',
#  'the balcony',
#  'the bed',
#  'the centre of Amsterdam',
#  'the centre of Koln Altstadt',
#  'the city center',
#  'the co · ordination between the working personnel',
#  'the elevator',
#  'the garden',
#  'the little gift when leaving',
#  'the manager',
#  'the only one visitor',
#  'the people who are working',
#  'the shopping center in the hotel',
#  'the smilling faces of the emploeys',
#  'the spa',
#  'the waiters in pirates',
#  'the water in the lagune and pond',
#  'the way they solved the food situation',
#  'this room',
#  'tiling round toilet area',
#  'time',
#  'to get there',
#  'toiletries',
#  'towels in the room',
#  'two main buffet restaurants',
#  'up to date flat screen',
#  'view of the mountains from my balcony',
#  'views',
#  'vouchers for meals and drinks',
#  'wash basin',
#  'water in the fridge',
#  'with regard to food',
#  'zone 1'}

# %%
df_opener_en_test
# Out:
#                                                                                                                          text  \
# 0                                                                                     They were there just to keep us happy .
# 1                                                   A wonderful place to go and we are planning to return as soon as we can .
# 2                                                   A wonderful place to go and we are planning to return as soon as we can .
# 3                                                                                 Thank you for such a wonderful experience .
# 4                                                                                              Hotel was under construction .
# ..                                                                                                                        ...
# 860  Front desk wasn 't the best , quite slow for passport registration and clerk insisted that we pay up for a better room .
# 861  Front desk wasn 't the best , quite slow for passport registration and clerk insisted that we pay up for a better room .
# 862                                                                 In · room breakfast was tasty and quite large , awesome .
# 863                                                                 In · room breakfast was tasty and quite large , awesome .
# 864                                                                 In · room breakfast was tasty and quite large , awesome .
#
#                                                                  sent_id  \
# 0    opener_en/kaf/hotel/english00148_ddb06f1e4ab012d85f9120c394168c48-6
# 1    opener_en/kaf/hotel/english00148_ddb06f1e4ab012d85f9120c394168c48-7
# 2    opener_en/kaf/hotel/english00148_ddb06f1e4ab012d85f9120c394168c48-7
# 3    opener_en/kaf/hotel/english00148_ddb06f1e4ab012d85f9120c394168c48-8
# 4    opener_en/kaf/hotel/english00028_2a1e03a3e5d6afe2c5024926cb7ff9ab-2
# ..                                                                   ...
# 860  opener_en/kaf/hotel/english00113_8161bacaf54503f451c7246b073003a5-8
# 861  opener_en/kaf/hotel/english00113_8161bacaf54503f451c7246b073003a5-8
# 862  opener_en/kaf/hotel/english00113_8161bacaf54503f451c7246b073003a5-9
# 863  opener_en/kaf/hotel/english00113_8161bacaf54503f451c7246b073003a5-9
# 864  opener_en/kaf/hotel/english00113_8161bacaf54503f451c7246b073003a5-9
#
#               Source Source_string Source_index                   Target  \
# 0    [[us], [29:31]]          [us]      [29:31]          [[They], [0:4]]
# 1           [[], []]            []           []       [[place], [12:17]]
# 2    [[we], [28:30]]          [we]      [28:30]                 [[], []]
# 3           [[], []]            []           []  [[experience], [31:41]]
# 4           [[], []]            []           []         [[Hotel], [0:5]]
# ..               ...           ...          ...                      ...
# 860         [[], []]            []           []   [[Front desk], [0:10]]
# 861         [[], []]            []           []   [[Front desk], [0:10]]
# 862         [[], []]            []           []   [[breakfast], [10:19]]
# 863         [[], []]            []           []   [[breakfast], [10:19]]
# 864         [[], []]            []           []   [[breakfast], [10:19]]
#
#     Target_string Target_index                    Polar_expression  \
# 0          [They]        [0:4]  [[to keep, happy], [21:28, 32:37]]
# 1         [place]      [12:17]               [[wonderful], [2:11]]
# 2              []           []     [[planning to return], [35:53]]
# 3    [experience]      [31:41]              [[wonderful], [21:30]]
# 4         [Hotel]        [0:5]     [[under construction], [10:28]]
# ..            ...          ...                                 ...
# 860  [Front desk]       [0:10]             [[quite slow], [30:40]]
# 861  [Front desk]       [0:10]       [[wasn 't the best], [11:27]]
# 862   [breakfast]      [10:19]            [[quite large], [34:45]]
# 863   [breakfast]      [10:19]                  [[tasty], [24:29]]
# 864   [breakfast]      [10:19]                [[awesome], [48:55]]
#
#     Polar_expression_string  ... Implicit_holder_exclusive H-A-O H-IA-IO  \
# 0          [to keep, happy]  ...                     False     1   False
# 1               [wonderful]  ...                      True     0   False
# 2      [planning to return]  ...                     False     0   False
# 3               [wonderful]  ...                      True     0   False
# 4      [under construction]  ...                      True     0   False
# ..                      ...  ...                       ...   ...     ...
# 860            [quite slow]  ...                      True     0   False
# 861      [wasn 't the best]  ...                      True     0   False
# 862           [quite large]  ...                      True     0   False
# 863                 [tasty]  ...                      True     0   False
# 864               [awesome]  ...                      True     0   False
#
#      H-A-IO  H-IA-O  IH-A-O  IH-A-IO  IH-IA-O  IH-IA-IO  Token Count
# 0     False   False   False    False    False     False           11
# 1     False   False    True    False    False     False           19
# 2     False    True   False    False    False     False           19
# 3     False   False    True    False    False     False           10
# 4     False   False    True    False    False     False            8
# ..      ...     ...     ...      ...      ...       ...          ...
# 860   False   False    True    False    False     False           27
# 861   False   False    True    False    False     False           27
# 862   False   False    True    False    False     False           14
# 863   False   False    True    False    False     False           14
# 864   False   False    True    False    False     False           14
#
# [865 rows x 28 columns]

# %%
df_opener_en_test.loc[0]['Target_string']
# Out:
# ['They']

# %%
df_opener_en_test[df_opener_en_test['sent_id'] == "opener_en/kaf/hotel/english00214_f731285c2d232cf15e5cdae66ab186b1-6"]
# Out:
#                                                                                                                    text  \
# 565  The first floor 24 hr bar was well run and no matter what time of day there was always a waiter on hand to serve .
# 566  The first floor 24 hr bar was well run and no matter what time of day there was always a waiter on hand to serve .
#
#                                                                  sent_id  \
# 565  opener_en/kaf/hotel/english00214_f731285c2d232cf15e5cdae66ab186b1-6
# 566  opener_en/kaf/hotel/english00214_f731285c2d232cf15e5cdae66ab186b1-6
#
#        Source Source_string Source_index                          Target  \
# 565  [[], []]            []           []  [[a waiter on hand], [87:103]]
# 566  [[], []]            []           []          [[24 hr bar], [16:25]]
#
#           Target_string Target_index               Polar_expression  \
# 565  [a waiter on hand]     [87:103]  [[there was always], [70:86]]
# 566         [24 hr bar]      [16:25]          [[well run], [30:38]]
#
#     Polar_expression_string  ... Implicit_holder_exclusive H-A-O H-IA-IO  \
# 565      [there was always]  ...                      True     0   False
# 566              [well run]  ...                      True     0   False
#
#      H-A-IO  H-IA-O  IH-A-O  IH-A-IO  IH-IA-O  IH-IA-IO  Token Count
# 565   False   False    True    False    False     False           28
# 566   False   False    True    False    False     False           28
#
# [2 rows x 28 columns]

# %%
df_en_roberta_largev1[df_en_roberta_largev1['sent_id'] == "opener_en/kaf/hotel/english00214_f731285c2d232cf15e5cdae66ab186b1-6"]
# Out:
#                                                                                                                    text  \
# 523  The first floor 24 hr bar was well run and no matter what time of day there was always a waiter on hand to serve .
# 524  The first floor 24 hr bar was well run and no matter what time of day there was always a waiter on hand to serve .
# 525  The first floor 24 hr bar was well run and no matter what time of day there was always a waiter on hand to serve .
# 526  The first floor 24 hr bar was well run and no matter what time of day there was always a waiter on hand to serve .
# 527  The first floor 24 hr bar was well run and no matter what time of day there was always a waiter on hand to serve .
#
#                                                                  sent_id  \
# 523  opener_en/kaf/hotel/english00214_f731285c2d232cf15e5cdae66ab186b1-6
# 524  opener_en/kaf/hotel/english00214_f731285c2d232cf15e5cdae66ab186b1-6
# 525  opener_en/kaf/hotel/english00214_f731285c2d232cf15e5cdae66ab186b1-6
# 526  opener_en/kaf/hotel/english00214_f731285c2d232cf15e5cdae66ab186b1-6
# 527  opener_en/kaf/hotel/english00214_f731285c2d232cf15e5cdae66ab186b1-6
#
#        Source Source_string Source_index                       Target  \
# 523  [[], []]            []           []  [[The first floor], [0:15]]
# 524  [[], []]            []           []  [[The first floor], [0:15]]
# 525  [[], []]            []           []             [[bar], [22:25]]
# 526  [[], []]            []           []        [[a waiter], [87:95]]
# 527  [[], []]            []           []        [[a waiter], [87:95]]
#
#          Target_string Target_index               Polar_expression  \
# 523  [The first floor]       [0:15]             [[24 hr], [16:21]]
# 524  [The first floor]       [0:15]          [[well run], [30:38]]
# 525              [bar]      [22:25]          [[well run], [30:38]]
# 526         [a waiter]      [87:95]  [[there was always], [70:86]]
# 527         [a waiter]      [87:95]          [[on hand], [96:103]]
#
#     Polar_expression_string  ... Implicit_target_exclusive  \
# 523                 [24 hr]  ...                     False
# 524              [well run]  ...                     False
# 525              [well run]  ...                     False
# 526      [there was always]  ...                     False
# 527               [on hand]  ...                     False
#
#     Implicit_holder_exclusive  H-A-O  H-IA-IO  H-A-IO  H-IA-O  IH-A-O  \
# 523                      True      0    False   False   False    True
# 524                      True      0    False   False   False    True
# 525                      True      0    False   False   False    True
# 526                      True      0    False   False   False    True
# 527                      True      0    False   False   False    True
#
#      IH-A-IO  IH-IA-O  IH-IA-IO
# 523    False    False     False
# 524    False    False     False
# 525    False    False     False
# 526    False    False     False
# 527    False    False     False
#
# [5 rows x 27 columns]

# %%
df_opener_en_test[df_opener_en_test['sent_id'] == "opener_en/kaf/hotel/english00214_f731285c2d232cf15e5cdae66ab186b1-6"]

# %%
df_en_roberta_largev1[df_en_roberta_largev1['text'].str.contains("24 hr bar")]
# Out:
#                                                                                                                    text  \
# 523  The first floor 24 hr bar was well run and no matter what time of day there was always a waiter on hand to serve .
# 524  The first floor 24 hr bar was well run and no matter what time of day there was always a waiter on hand to serve .
# 525  The first floor 24 hr bar was well run and no matter what time of day there was always a waiter on hand to serve .
# 526  The first floor 24 hr bar was well run and no matter what time of day there was always a waiter on hand to serve .
# 527  The first floor 24 hr bar was well run and no matter what time of day there was always a waiter on hand to serve .
#
#                                                                  sent_id  \
# 523  opener_en/kaf/hotel/english00214_f731285c2d232cf15e5cdae66ab186b1-6
# 524  opener_en/kaf/hotel/english00214_f731285c2d232cf15e5cdae66ab186b1-6
# 525  opener_en/kaf/hotel/english00214_f731285c2d232cf15e5cdae66ab186b1-6
# 526  opener_en/kaf/hotel/english00214_f731285c2d232cf15e5cdae66ab186b1-6
# 527  opener_en/kaf/hotel/english00214_f731285c2d232cf15e5cdae66ab186b1-6
#
#        Source Source_string Source_index                       Target  \
# 523  [[], []]            []           []  [[The first floor], [0:15]]
# 524  [[], []]            []           []  [[The first floor], [0:15]]
# 525  [[], []]            []           []             [[bar], [22:25]]
# 526  [[], []]            []           []        [[a waiter], [87:95]]
# 527  [[], []]            []           []        [[a waiter], [87:95]]
#
#          Target_string Target_index               Polar_expression  \
# 523  [The first floor]       [0:15]             [[24 hr], [16:21]]
# 524  [The first floor]       [0:15]          [[well run], [30:38]]
# 525              [bar]      [22:25]          [[well run], [30:38]]
# 526         [a waiter]      [87:95]  [[there was always], [70:86]]
# 527         [a waiter]      [87:95]          [[on hand], [96:103]]
#
#     Polar_expression_string  ... Implicit_target_exclusive  \
# 523                 [24 hr]  ...                     False
# 524              [well run]  ...                     False
# 525              [well run]  ...                     False
# 526      [there was always]  ...                     False
# 527               [on hand]  ...                     False
#
#     Implicit_holder_exclusive  H-A-O  H-IA-IO  H-A-IO  H-IA-O  IH-A-O  \
# 523                      True      0    False   False   False    True
# 524                      True      0    False   False   False    True
# 525                      True      0    False   False   False    True
# 526                      True      0    False   False   False    True
# 527                      True      0    False   False   False    True
#
#      IH-A-IO  IH-IA-O  IH-IA-IO
# 523    False    False     False
# 524    False    False     False
# 525    False    False     False
# 526    False    False     False
# 527    False    False     False
#
# [5 rows x 27 columns]

# %%
es_target_diff_test = es_target_tokens_test.difference(es_target_tokens_pred)
es_target_diff_pred = es_target_tokens_test.difference(es_target_tokens_pred)

print(len(es_target_diff_test),len(es_target_tokens_test), len(es_target_tokens_pred))
# Out:
# 215 472 370

# %%
es_target_diff_test
# Out:
# {'7 dias',
#  'APARTAMENTO',
#  'Algo',
#  'Alojamiento',
#  'Camas de 1,05',
#  'Camp Nou',
#  'El Gran Bahía Principe Ambar',
#  'El complejo',
#  'El tamaño de la habitación y el baño',
#  'Fin de semana',
#  'La comida y cena',
#  'Los de recepción',
#  'Museos',
#  'Neptuno',
#  'Puerta del Sol',
#  'Sol',
#  'Tiendas',
#  'WIFI',
#  'a lounge',
#  'a todos lados',
#  'acogimiento por parte de todos los empleados',
#  'actividades',
#  'acudir a un musical',
#  'aire acondicionado',
#  'al estadio de futbol del barca',
#  'algo',
#  'amplitud de menu',
#  'autobus',
#  'bandeja de infusiones y café',
#  'bar',
#  'barandillas',
#  'baños',
#  'bollería',
#  'brares',
#  'bus urbanos.se',
#  'cadena Playa Senator',
#  'cafes',
#  'cafetera eléctrica',
#  'calidad',
#  'camas queen',
#  'centro de Peñiscola',
#  'cereales',
#  'cesta de frutas',
#  'cines',
#  'con Moet Chandon',
#  'congreso de los diputados',
#  'conocer la ciudad',
#  'cualquier punto monumental de la ciudad',
#  'cuarto de baño',
#  'cuartos',
#  'cuidado',
#  'cultura',
#  'de Sevilla capital',
#  'de cocoteros',
#  'de nuestra estancia',
#  'de todo',
#  'decoracion',
#  'del Nou Camp',
#  'del camp nou',
#  'del servicio',
#  'del transporte público',
#  'descansa',
#  'descansar',
#  'detallitos',
#  'diseño',
#  'dos hamacas',
#  'el aire acondicionado',
#  'el apartamento',
#  'el bullicio de la gente',
#  'el clima',
#  'el de recepcion',
#  'el del hotel',
#  'el desayuno bufet',
#  'el detalle de una botella de cava',
#  'el fiambre',
#  'el gimnasio',
#  'el hote',
#  'el lobby del Hotel',
#  'el mantel',
#  'el olor a orine viejo',
#  'el personal de limpieza',
#  'el personal de recepción',
#  'el queso',
#  'el resto',
#  'el servicio de habitaciones',
#  'el telefono',
#  'el trato recibido',
#  'en alojarme otra vez alli',
#  'en las paredes',
#  'escritorio',
#  'ese aspecto',
#  'ese tipo de instalaciones',
#  'eso',
#  'esta cadena',
#  'este',
#  'etc.las habitaciones',
#  'excesivo ruido dentro de la habitación',
#  'fachada',
#  'fin de semana',
#  'friobar',
#  'gastronoma',
#  'hotel de Madrid',
#  'hotel palladium punta cana',
#  'iluminosidad',
#  'indicacion concreta ni acompanamiento de personal',
#  'infusiones',
#  'internet',
#  'inversión en formación en idiomas',
#  'ir de compras',
#  'la animacion',
#  'la azote',
#  'la cama supletoria',
#  'la estación de tren',
#  'la estación del AVE',
#  'la fachada',
#  'la impieza',
#  'la localizacion',
#  'la oferta',
#  'la operadora',
#  'la plaza del duomo',
#  'la reposicion del minibar',
#  'la restauración',
#  'la situación',
#  'la ubicación del hotel',
#  'la zona de los múseos',
#  'la zona donde está',
#  'las sabanas',
#  'lo cual',
#  'lo demás',
#  'localización',
#  'los 2 jacuzzy',
#  'los jardines',
#  'los nórdicos',
#  'los trabajadores',
#  'lugar para descansar en familia',
#  'medidas de seguridad apropiadas',
#  'miinibar',
#  'mis expectativas de comodidad y tranquilida',
#  'mogollon de reclamaciones',
#  'muchos desperfectos',
#  'nada de nada',
#  'ninguno de los dos',
#  'no oir ni un solo ruido',
#  'nuestra decision',
#  'otras bebidas',
#  'para llegar a la playa',
#  'para ver el musical " El Rey León',
#  'parking',
#  'patio interior',
#  'pequeña cafetera',
#  'pequeñas frutas tropicales',
#  'piscina',
#  'piscinas',
#  'plaza Mayor',
#  'por dejar unas horas mas el coche en el garaje',
#  'prensa',
#  'puerta del sol',
#  'recepción 24 horas',
#  'reclamar',
#  'relación calidad precio',
#  'ruidos',
#  'sala',
#  'semejante complejo',
#  'servicio de fax',
#  'shushi',
#  'sitios de ocio',
#  'sitios para tomar algo',
#  'sol',
#  'spa',
#  'su albornoz',
#  'su arteria principal ( Gran Via',
#  'su buffet libre',
#  'su ubicacon',
#  'tapear por los numerosos bares de la zona',
#  'tema aparcamiento',
#  'terraza',
#  'tiendas',
#  'todas las facilidades',
#  'todo el personal',
#  'todo eso',
#  'todo incluído',
#  'todo lo que deseas',
#  'todo lo que se necesita',
#  'todo lo que se necesite.',
#  'todos los aspectos',
#  'trato que recibimos del personal',
#  'ubicacion',
#  'ubicación para visitar los lugares de interés turístico',
#  'un calentador de agua',
#  'un desayuno',
#  'un lavado de cara',
#  'un personal',
#  'un poco de mantenimiento',
#  'un sitio',
#  'un vehiculo',
#  'una entrada de metro',
#  'una entrada gratuita al spa',
#  'una experiencia',
#  'una habitación',
#  'una intimidad para acceder',
#  'una parada',
#  'una recepción más amplia y luminosa',
#  'una zona de Madrid',
#  'unas mantas para abrigarnos',
#  'unas vistas',
#  'unos bares',
#  'unos dias',
#  'unos jacuzzy',
#  'varios detalles',
#  'verlo todo eso',
#  'visitarlo',
#  'wifi con acceso abierto a internet',
#  'zona',
#  'zona de playa',
#  'zonas de aparcamiento'}

# %% [markdown]
# ## Holder

# %%
en_holder_diff_test = en_holder_tokens_test.difference(en_holder_tokens_pred)
en_holder_diff_pred = en_holder_tokens_pred.difference(en_holder_tokens_test)

print(len(en_holder_tokens_test), len(en_holder_tokens_pred))

print(len(en_holder_diff_test),len(en_holder_diff_pred))
# Out:
# 10 12
# 5 7

# %%
en_holder_diff_test

# find you, me holder sentences
# Out:
# {'all eight couples', 'eyes.I', 'me', 'my experience', 'you'}

# %%
en_holder_diff_pred
# Out:
# {'building',
#  'everyone',
#  'he',
#  'many different activities',
#  'reason',
#  'the linen',
#  'the room'}

# %%
es_holder_diff_test = es_holder_tokens_test.difference(es_holder_tokens_pred)
es_holder_diff_pred = es_holder_tokens_pred.difference(es_holder_tokens_test)

print(len(es_holder_tokens_test), len(es_holder_tokens_pred))

print(len(es_holder_diff_test),len(es_holder_diff_pred))
# Out:
# 8 3
# 5 0

# %%
print(es_holder_diff_test , es_holder_diff_pred) # check yo, nosotros
# Out:
# {'me', 'hemos', 'Yo', 'nosotros', 'yo'} set()

# %%
## Set Expression

# %%
en_express_diff_test = en_expression_tokens_test.difference(en_expression_tokens_pred)
en_express_diff_pred = en_expression_tokens_pred.difference(en_expression_tokens_test)

print(len(en_expression_tokens_test), len(en_expression_tokens_pred))

print(len(en_express_diff_test),len(en_express_diff_pred))
# Out:
# 594 547
# 220 173

# %%
en_express_diff_test
# Out:
# {"'s not worth",
#  '12 times',
#  'BEST',
#  'Central',
#  'Clean',
#  'Dirty.our',
#  'Friendly',
#  'Greek dishes with a general European twist',
#  'Many people',
#  'NOT to eat in the buffet restaurant',
#  'Not',
#  'One of the best holidays',
#  'Only',
#  'Relax and enjoy',
#  'Robbed in elevator of hotel !',
#  'Similar to',
#  'There are not',
#  'There is no',
#  'To be avoided at all costs',
#  'To expensive',
#  'Took',
#  'Totally overpriced',
#  'Within 7 minutes',
#  'a good option in this category',
#  'a happy',
#  'a real 4star hotel',
#  'a top hotel !',
#  'abit repetitive at times',
#  'accompanied by a live singer',
#  'advise everyone',
#  "all in length , which isn 't the most convenient",
#  'all tastes',
#  'already booked',
#  'already went 14 times',
#  'always will remember with joy and happiness',
#  'annoying to wait for',
#  'are satisfied',
#  'at affordable prices',
#  'attrackts back packing , party focused youngsters',
#  'bad quality',
#  'be definitely back soon !',
#  'bit dated',
#  'black mould on tiling',
#  'boasts outstanding architecture',
#  'booked again',
#  'brocken',
#  'budget',
#  'buffet',
#  'can be considered if you can cope with the noise',
#  'candy',
#  'cannot wait until I can go back again',
#  'centrally located',
#  'changed',
#  'chic !',
#  'chipped',
#  'cleaned',
#  'cleaned every day',
#  'close to',
#  'close to airport',
#  'could be a little improved',
#  'could do with less jelly fish',
#  'could not have been better',
#  'dark',
#  'decent',
#  'did not understand much english',
#  "didn 't care at all for the complaints",
#  "didn 't know the hotel restaurant / bar menu",
#  'disaster',
#  'does not include any other restaurant',
#  "don 't go",
#  "don 't refund",
#  'easy to get',
#  'efficient',
#  'empty',
#  'encountered',
#  'enjoyed',
#  'everything you need',
#  'extra',
#  'fantastically clean',
#  'fist hole in bedroom door',
#  'for a week',
#  'for dinner',
#  'for dinner you have to wait in a queue',
#  'friendly.',
#  'fully visible from the outside',
#  'get',
#  'good quality',
#  'got',
#  'great fun',
#  'great value',
#  'had a brilliant time',
#  'had a table all to ourselves',
#  'had to pay 20 Euro',
#  'had to pay for',
#  'had to sit on towels',
#  'had to squeeze in order to fit between the shower and wall to get to the toilet',
#  'happy',
#  'hard to leave it !',
#  'have',
#  'have spoken very highly of this hotel to my friends and colleagues',
#  'have tea coffee making facilties',
#  'have to queue for',
#  'have to wait',
#  'helpful in providing directions and general info',
#  'helpfull',
#  'highly recommend',
#  'hours',
#  'in a very nice location on the golf field',
#  'in other part',
#  'including',
#  'just cross the boulevar du Periferique',
#  'just functional',
#  'let alone',
#  'like',
#  'loads of',
#  'located among the vineyards and olive trees',
#  'looking to come back next year',
#  'looks a bit dated',
#  'lots of space',
#  'lousy',
#  'loved staying',
#  'maintained',
#  'maximum',
#  'may look great',
#  'meals in the main self sevice restaurant',
#  'might',
#  'mini fridge.',
#  'more than 700',
#  'moved out',
#  'near',
#  'nearby',
#  'negative',
#  'never have',
#  'new',
#  'nice alternation',
#  'no diversity',
#  'no place to hang something more than two shirts',
#  'no place to put luggage',
#  'noise',
#  'nor too small',
#  'not have been able to cook a meal',
#  'not international',
#  'not kind',
#  'not like',
#  'not pleasant',
#  'not run down or anything',
#  'odd stains on sofa',
#  'offered',
#  'ok.',
#  'open daily',
#  'over look the pool.',
#  'painting',
#  'perfekt',
#  'planning to return',
#  'plenty of very good',
#  'private',
#  'profession',
#  'provides a prefect " base camp "',
#  'quite easily by using a nearby bus',
#  'quite slow',
#  'reach',
#  'reachable after 166 steps downstairs ( or upstairs )',
#  'really kind',
#  'really small',
#  'reasonable in terms of a place to sleep',
#  'relaxing',
#  'rotten',
#  'seemed to be taken',
#  'service minded',
#  'shopping center " Diagonal Mar "',
#  'should be included',
#  'slendid',
#  'smoked everywhere',
#  'so helpful',
#  'so kind',
#  'spend the extra money',
#  'spoilt',
#  'stay in a better one',
#  'stopped foor several moments',
#  'supported our needs throughout the visit',
#  'takes no responsibility',
#  'the most picturesque of Tuscany',
#  'there are many',
#  'to consider when you just want to spend a night and get fast to the airport first thing in the morning',
#  'to keep',
#  'to make your holiday perfect',
#  'to stay when you want to visit Paris',
#  'too huge',
#  'treated to a full breakfast daily',
#  'trying very , very , very friendly',
#  'uncomfortable',
#  'understanding',
#  'very cozy',
#  'very easy to travel to anywhere',
#  'very funny',
#  'very spacious',
#  'very sunny',
#  'very warm',
#  'walking distance to the metro',
#  'warmly welcomed by all the staff',
#  'was',
#  'was not cleaned properly',
#  'was taking place',
#  "wasn 't sufficient",
#  'well laid out',
#  'were kept tidy',
#  'were made to feel very welcome',
#  'were not sure',
#  'will like',
#  'will not forget',
#  'willing to assist',
#  'with a lake',
#  'with a view on Nevskii',
#  'with all necessary infrastructure',
#  'with swipe card access',
#  'with twin mattresses',
#  'work very hard',
#  'worked fine',
#  'working',
#  'would take an hour or so'}

# %%
es_express_diff_test = es_expression_tokens_test.difference(es_expression_tokens_pred)
es_express_diff_pred = es_expression_tokens_pred.difference(es_expression_tokens_test)

print(len(es_expression_tokens_test), len(es_expression_tokens_pred))

print(len(es_express_diff_test),len(es_express_diff_pred))
# Out:
# 688 530
# 331 173

# %%
es_express_diff_test
# Out:
# {'%',
#  '0,50 €',
#  '10 · 15 min.',
#  '2,5 €',
#  'Bien',
#  'Comodidad',
#  'Descanso',
#  'ESTUPENDO',
#  'El gran problema',
#  'En este sentido deja mucho que desear',
#  'Enhorabuena',
#  'Ideal para pasar un fin de semana de turismo por la capital',
#  'Imposible',
#  'Inútil',
#  'La cercanía',
#  'Lamentable',
#  'Llegando a la madrugada no hubo',
#  'Lo unico q vale',
#  'Muy amable',
#  'Muy amables',
#  'Muy bien',
#  'Muy bien ubicado',
#  'Muy buenas',
#  'NI OS ACERQUÉIS',
#  'No',
#  'No es un',
#  'Nos encantaría volver',
#  'Problemas con el estado de la cama',
#  'Remoñones',
#  'Repetiremos',
#  'Repetiremos sin duda',
#  'Tranquilo',
#  'Tuvieron',
#  'Una verdader tortura',
#  'a 15 minutos andando',
#  'a 5 minutos',
#  'a cualquier hora',
#  'a la altura de un resort !',
#  'a la entrada',
#  'a pesar de tener ya algunos años',
#  'a una parada de metro',
#  'abusando',
#  'acogedor',
#  'aconsejan',
#  'aconsejaria',
#  'acorde a la categoria de hotel',
#  'acorde con las características que ofrecen',
#  'al igual que',
#  'al lado',
#  'alejado',
#  'algo apartado del centro',
#  'algo caro',
#  'algo falto de calidad para un cuatro estrellas.',
#  'alguna grieta',
#  'amplio',
#  'amplios',
#  'arrepiento',
#  'atentos',
#  'aunque en Bormujos',
#  'aunque parezca lejana del centro de la ciudad',
#  'bastante usadas',
#  'bien agradable',
#  'bien cuidado / reformado',
#  'bien dispuesta',
#  'bordes',
#  'buen estado',
#  'bueno ver el Barsa',
#  'buffet',
#  'caro ( 15 €',
#  'casi casi',
#  'cercana',
#  'cerraba a las 23:00 h',
#  'cobrando 9 € diarios',
#  'como en todos los hoteles playa',
#  'con',
#  'con apenas',
#  'con balcón / mirador a G.Vía.',
#  'con encanto familiar',
#  'con gran calidad',
#  'con terraza',
#  'contaba',
#  'continuarán con',
#  'correcto para un cuatro estrellas',
#  'cortado muy , muy fino',
#  'crei',
#  'cuenta',
#  'cumple con su " obligación "',
#  'cumple con todo lo que uno puede esperar',
#  'da',
#  'de 4 estrellas',
#  'de ocio en madrid',
#  'del tipo casero',
#  'desastroso',
#  'desconocido para los huespedes',
#  'discuten',
#  'disfrutar',
#  'distincto',
#  'divinos',
#  'dormido fenomenal',
#  'educado',
#  'el alardeo',
#  'el relax',
#  'en el centro Madrid',
#  'en el corazón de Madrid',
#  'en la almohada',
#  'en la animada',
#  'en la azotea tenian',
#  'en pleno centro de Madrid',
#  'en pleno centro de la ciudad',
#  'encantada',
#  'encantador',
#  'entrada directa a la playa',
#  'era amplia',
#  'era escasìsimo',
#  'es aceptable',
#  'es genial',
#  'es ideal si vas a la zona de los teatros',
#  'es inmejorable',
#  'es muy atento',
#  'es muy grande',
#  'es poco amplio',
#  'es un poco elevado para la zona en la que esta situada en la ciudad',
#  'espacio natural',
#  'espectaculares',
#  'esta a un paso',
#  'esta en plena',
#  'esta enfrente del hotel',
#  'esta muy bien ubicado',
#  'esta situado en lo mejor de',
#  'estaban',
#  'estafaron',
#  'estamos muy contentos',
#  'estava cerrado',
#  'estava un poco turvia por no decir sucia',
#  'estupendos',
#  'está a tan solo 15 minutos de esta',
#  'está bien',
#  'está situado en todo el centro de Madrid',
#  'están rehabilitando',
#  'evitar',
#  'excelente !',
#  'falta de pintura en',
#  'fatal',
#  'feliz con',
#  'fue acertada.',
#  'fuimos',
#  'funcinando',
#  'funcionaban los chorros',
#  'gestionaba una empresa externa',
#  'grades',
#  'gran cosa',
#  'gratuíto',
#  'gustado mucho',
#  'gustó',
#  'gustó mucho',
#  'ha decepcionado',
#  'ha sido una gozada',
#  'había toda la variedad de otros hoteles playa',
#  'hay que pedir reserva',
#  'hemos sentido bien atendidos',
#  'hicimos',
#  'ideal para conocer Mequinez',
#  'ideal para escapadas urbanas',
#  'ideal para poder visitar cualquier punto de Madrid',
#  'ideal para viajes relacionados con el fútbol',
#  'incluido',
#  'inexistente en la zona',
#  'inmensa',
#  'inolvidable',
#  'joven',
#  'la calidad',
#  'la puerta del hotel',
#  'lejos',
#  'limpia',
#  'lo he pasado muy bien',
#  'lo suben al momento.',
#  'lo unico bueno',
#  'lujoso',
#  'magnifica',
#  'magnifico',
#  'mala',
#  'malo malisimo',
#  'maravilloso',
#  'maravilloso !',
#  'mejor de lo que esperaba',
#  'mis expectativas eran mayores',
#  'muchas',
#  'muchos arboles',
#  'muy aceptable',
#  'muy bien aisladas',
#  'muy bien comunicado con',
#  'muy bien cuidados',
#  'muy bien situado',
#  'muy bonita',
#  'muy buen aspecto',
#  'muy comodo',
#  'muy concurrida',
#  'muy cuidadas',
#  'muy céntrico',
#  'muy inferiores a un hotel de esta categoría',
#  'muy lento',
#  'muy muy flojo',
#  'muy recomendable',
#  'muy silenciosa',
#  'muy tranquilo',
#  'nada',
#  'nada de lo prometido',
#  'nada mas salir de la puerta del hotel',
#  'nada que ver con lo que',
#  'necesita una reforma',
#  'ni',
#  'ni caso',
#  'no aguantamos más',
#  'no cobrar nada',
#  'no creo que regrese',
#  'no desprecio',
#  'no dudare',
#  'no en la misma puerta del sol',
#  'no encontramos',
#  'no era nada espectacular',
#  'no es necesario',
#  'no escojais',
#  'no estaría mal',
#  'no está céntrico',
#  'no había',
#  'no hay',
#  'no hay ruidos',
#  'no he tenido problema para aparcar en la zona',
#  'no se escucha nada de ruido',
#  'no se oye absolutamente nada',
#  'no son muy grandes',
#  'no tiene',
#  'no todos los dias cambiaban',
#  'no vendria nada mal',
#  'noche',
#  'numerosos',
#  'ofertaron',
#  'ofrecen',
#  'pagamos 280 euros mas',
#  'para ir al Spa cada persona tiene',
#  'para nada',
#  'para solventar el problema',
#  'para sus huéspedes',
#  'para todos',
#  'pasamos de total relax',
#  'pelin pequeñas',
#  'perfecta para acceder de forma rápida al aeropuerto',
#  'pesimas',
#  'pesimo',
#  'poco donde elegir',
#  'poco servicial y orientado al cliente extrajero',
#  'poder aparcar',
#  'podiamos subir',
#  'ponen',
#  'por unos 35 euros por cabeza dormimos estupendamente',
#  'preciosa',
#  'preciosas',
#  'proxima',
#  'puedes encontrar',
#  'puedes ir andando',
#  'pusieron',
#  'párrafo aparte',
#  'que funciona de maravilla.No',
#  'que no reponen cuando se acaba',
#  'que pocos hoteles lo ofrecen',
#  'que te absorba la tranquilidad',
#  'realmente atento',
#  'realmente se puede',
#  'recién reformado',
#  'recomiendo 100',
#  'recomiendo para familias',
#  'relajarse',
#  'respetaron',
#  'resultó cómodo',
#  'resultó de gran utilidad para los niños',
#  'retirado',
#  'retirado del centro',
#  'satisfactorio',
#  'se merece',
#  'se puede esperar más',
#  'se puede ir paseando',
#  'se quedan cortos.',
#  'se sale',
#  'se tarda en urbano mas de media hora',
#  'sentir como reyes',
#  'serviciales.',
#  'si estas solo',
#  'si para parejas',
#  'siempre dispuesto',
#  'siempre nos reciben con',
#  'simpatico',
#  'simpaticos',
#  'sin dudas elegiria',
#  'sin faltarle',
#  'sin ningún interes en atender al cliente',
#  'sin variedad',
#  'situado al lado',
#  'situado en el centro de madrid',
#  'situado en plena',
#  'situado en primera linea de playa',
#  'situado practicamente en el centro de Milan',
#  'son amplias',
#  'son de calidad',
#  'sorprendio muchisimo',
#  'su cercanía',
#  'suficiente cantidad',
#  'suficiente para pasar un rato agradable',
#  'super recomiendo',
#  'super · relajante',
#  'tambièn tienes que estar mendigando',
#  'tan poca',
#  'te atendienden con mucho respeto , saber estar y con educación',
#  'te cogen',
#  'te incluia',
#  'te sientes muy bien',
#  'tenido que dejar',
#  'tiene todo para satisfacer a los clientes',
#  'tiene unas vistas espectaculares',
#  'tienen',
#  'tienes',
#  'todo un lujo',
#  'tuvieron',
#  'un paraíso',
#  'un poco escaso',
#  'una desilusion',
#  'vendría magníficamente',
#  'verse mal casi todos los canales',
#  'visitase',
#  'vistas a la rotonda',
#  'volveremos',
#  'vovere'}

# %% [markdown]
# # Transformer, token length

# %%
fpath = !pwd

from transformers import AutoTokenizer

plm_model_name = 'roberta-large'
plm_model_path= f'{fpath[0]}/pretrained_models/roberta-large'
tokenizer = AutoTokenizer.from_pretrained(plm_model_path)

length = len(tokenizer.encode('text'))
length
# Out:
# 3

# %%
# Create a new column with the number of words from the 'text' column
df_opener_en_test['Token Count'] = df_opener_en_test['text'].apply(lambda x: len(tokenizer.encode(x)))
df_opener_es_test['Token Count'] = df_opener_es_test['text'].apply(lambda x: len(tokenizer.encode(x)))

# %%
df_en_roberta_largev1[df_en_roberta_largev1['sent_id'] == "opener_en/kaf/hotel/english00134_94658e39af0d72b00ead2ac314bf7074-2"]
df_opener_en_test[df_opener_en_test['sent_id'] == "opener_en/kaf/hotel/english00214_f731285c2d232cf15e5cdae66ab186b1-6"]
# Out:
#                                                                                                                    text  \
# 565  The first floor 24 hr bar was well run and no matter what time of day there was always a waiter on hand to serve .
# 566  The first floor 24 hr bar was well run and no matter what time of day there was always a waiter on hand to serve .
#
#                                                                  sent_id  \
# 565  opener_en/kaf/hotel/english00214_f731285c2d232cf15e5cdae66ab186b1-6
# 566  opener_en/kaf/hotel/english00214_f731285c2d232cf15e5cdae66ab186b1-6
#
#        Source Source_string Source_index                          Target  \
# 565  [[], []]            []           []  [[a waiter on hand], [87:103]]
# 566  [[], []]            []           []          [[24 hr bar], [16:25]]
#
#           Target_string Target_index               Polar_expression  \
# 565  [a waiter on hand]     [87:103]  [[there was always], [70:86]]
# 566         [24 hr bar]      [16:25]          [[well run], [30:38]]
#
#     Polar_expression_string  ... Implicit_holder_exclusive H-A-O H-IA-IO  \
# 565      [there was always]  ...                      True     0   False
# 566              [well run]  ...                      True     0   False
#
#      H-A-IO  H-IA-O  IH-A-O  IH-A-IO  IH-IA-O  IH-IA-IO  Token Count
# 565   False   False    True    False    False     False           28
# 566   False   False    True    False    False     False           28
#
# [2 rows x 28 columns]

# %%
# df_opener_en_test.sort_values(by="Token Count", ascending=False)

df_opener_en_test[df_opener_en_test['sent_id'] =='opener_en/kaf/hotel/english00134_94658e39af0d72b00ead2ac314bf7074-2']['text']

# df_opener_en_test[df_opener_en_test['sent_id'] =='opener_en/kaf/hotel/english00134_94658e39af0d72b00ead2ac314bf7074-2']
# Out:
# 56    really nice hotel , well laid out all rooms over look the pool. rooms are nice and large have tea coffee making facilties , mini fridge. loads of ...
# 57    really nice hotel , well laid out all rooms over look the pool. rooms are nice and large have tea coffee making facilties , mini fridge. loads of ...
# 58    really nice hotel , well laid out all rooms over look the pool. rooms are nice and large have tea coffee making facilties , mini fridge. loads of ...
# 59    really nice hotel , well laid out all rooms over look the pool. rooms are nice and large have tea coffee making facilties , mini fridge. loads of ...
# 60    really nice hotel , well laid out all rooms over look the pool. rooms are nice and large have tea coffee making facilties , mini fridge. loads of ...
# 61    really nice hotel , well laid out all rooms over look the pool. rooms are nice and large have tea coffee making facilties , mini fridge. loads of ...
# 62    really nice hotel , well laid out all rooms over look the pool. rooms are nice and large have tea coffee making facilties , mini fridge. loads of ...
# 63    really nice hotel , well laid out all rooms over look the pool. rooms are nice and large have tea coffee making facilties , mini fridge. loads of ...
# 64    really nice hotel , well laid out all rooms over look the pool. rooms are nice and large have tea coffee making facilties , mini fridge. loads of ...
# 65    really nice hotel , well laid out all rooms over look the pool. rooms are nice and large have tea coffee making facilties , mini fridge. loads of ...
# 66    really nice hotel , well laid out all rooms over look the pool. rooms are nice and large have tea coffee making facilties , mini fridge. loads of ...
# 67    really nice hotel , well laid out all rooms over look the pool. rooms are nice and large have tea coffee making facilties , mini fridge. loads of ...
# 68    really nice hotel , well laid out all rooms over look the pool. rooms are nice and large have tea coffee making facilties , mini fridge. loads of ...
# 69    really nice hotel , well laid out all rooms over look the pool. rooms are nice and large have tea coffee making facilties , mini fridge. loads of ...
# 70    really nice hotel , well laid out all rooms over look the pool. rooms are nice and large have tea coffee making facilties , mini fridge. loads of ...
# 71    really nice hotel , well laid out all rooms over look the pool. rooms are nice and large have tea coffee making facilties , mini fridge. loads of ...
# 72    really nice hotel , well laid out all rooms over look the pool. rooms are nice and large have tea coffee making facilties , mini fridge. loads of ...
# 73    really nice hotel , well laid out all rooms over look the pool. rooms are nice and large have tea coffee making facilties , mini fridge. loads of ...
# Name: text, dtype: object

# %%
df_opener_es_test.sort_values(by="Token Count", ascending=False)[:3]
# Out:
#                                                                                                                                                      text  \
# 15  Es un hotel muy casero en todo lo que respecta al trato y a la comida , personal muy atento y simpatico , esta situado en primera linea de playa y...
# 9   Es un hotel muy casero en todo lo que respecta al trato y a la comida , personal muy atento y simpatico , esta situado en primera linea de playa y...
# 18  Es un hotel muy casero en todo lo que respecta al trato y a la comida , personal muy atento y simpatico , esta situado en primera linea de playa y...
#
#                                                                 sent_id  \
# 15  opener_es/kaf/hotel/spanish00172_bf69ca6910c0aa687b0eab91d0353fd1-2
# 9   opener_es/kaf/hotel/spanish00172_bf69ca6910c0aa687b0eab91d0353fd1-2
# 18  opener_es/kaf/hotel/spanish00172_bf69ca6910c0aa687b0eab91d0353fd1-2
#
#       Source Source_string Source_index                            Target  \
# 15  [[], []]            []           []  [[un lavado de cara], [535:552]]
# 9   [[], []]            []           []                [[trato], [50:55]]
# 18  [[], []]            []           []         [[mobiliario], [647:657]]
#
#           Target_string Target_index                 Polar_expression  \
# 15  [un lavado de cara]    [535:552]          [[necesita], [526:534]]
# 9               [trato]      [50:55]          [[muy casero], [12:22]]
# 18         [mobiliario]    [647:657]  [[bastante antiguo], [658:674]]
#
#    Polar_expression_string  ... Implicit_holder_exclusive H-A-O H-IA-IO  \
# 15              [necesita]  ...                      True     0   False
# 9             [muy casero]  ...                      True     0   False
# 18      [bastante antiguo]  ...                      True     0   False
#
#     H-A-IO  H-IA-O  IH-A-O  IH-A-IO  IH-IA-O  IH-IA-IO  Token Count
# 15   False   False    True    False    False     False          220
# 9    False   False    True    False    False     False          220
# 18   False   False    True    False    False     False          220
#
# [3 rows x 28 columns]

# %% [markdown]
# ## Implicit Percentages

# %%
def json_eda(df):
# some basic counts and percentages
    
    sentances = df['sent_id'].nunique()
    holders = len(df[df['Source_string'].apply(len) > 0])
    targets = len(df[df['Target_string'].apply(len) > 0])
    polarity = len(df[df['Polarity'].apply(len) > 0])
    expression = len(df[df['Polar_expression_string'].apply(len) > 0])

    print(f'n sentances: {sentances} \nn holders: {holders} \nn targets: {targets} \nn polarity: {polarity} \nn expression: {expression}')

    perIH = df['Implicit_holder'].sum()/len(df)
    perIT = df['Implicit_target'].sum()/len(df)
    perIE = df['Implicit_expression'].sum()/len(df)
    perIHIT = df['Implicit_holder_target'].sum()/len(df)
    exclIT = df['Implicit_target_exclusive'].sum()/len(df)
    exclIH = df['Implicit_holder_exclusive'].sum()/len(df)

    print(f'\nImplicit percentages in the dataset: \npercent implicit holder: {perIH},\npercent implicit target: {perIT},\npercent implicit holder implicit target: {perIHIT}, \npercent implicit expression: {perIE}')

    print(f'\nImplicit target exclusive: {exclIT}')
    print(f'\nImplicit holder exclusive: {exclIH}')

    HAO=df['H-A-O'].sum()/len(df)
    HIAIO=df['H-IA-IO'].sum()/len(df)
    HAIO=df['H-A-IO'].sum()/len(df)
    HIAO=df['H-IA-O'].sum()/len(df)
    IHAO=df['IH-A-O'].sum()/len(df)
    IHAIO=df['IH-A-IO'].sum()/len(df)
    IHIAO=df['IH-IA-O'].sum()/len(df)

    print(f'H-A-O: {HAO}')
    print(f'H-IA-IO: {HIAIO}')
    print(f'H-A-IO: {HAIO}')
    print(f'H-IA-O: {HIAIO}')
    print(f'IH-A-O: {IHAO}')
    print(f'IH-A-IO: {IHAIO}')
    print(f'IH-IA-O: {IHIAO}')
        

    cross_polarity_intensity = pd.crosstab(df['Polarity'], df['Intensity'], margins = True, normalize='all') * 100
    display(cross_polarity_intensity)

    df_count_per_sent = pd.DataFrame(df.groupby(['sent_id'])['Polar_expression'].count())

    count_mult_opinion =  (df_count_per_sent['Polar_expression'] > 1).sum()
    perc_mult_opinion = (df_count_per_sent['Polar_expression'] > 1).sum() / df.shape[0]

    print(f'The total count of sentiments with multiple opinions is: {count_mult_opinion}')
    print(f'The percent of sentiments with multiple opinions is: {perc_mult_opinion}')

# %%
json_eda(df_en_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 json_eda(df_en_train)
#
# NameError: name 'df_en_train' is not defined

# %%
# df_en_train = normalize_jsons("data/opener_en/train.json")
# df_es_train = normalize_jsons("data/opener_es/train.json")
# df_en_dev = normalize_jsons("data/opener_en/dev.json")
# df_es_dev = normalize_jsons("data/opener_es/dev.json")
# df_en_test = normalize_jsons("data/opener_en/test.json")
# df_es_test = normalize_jsons("data/opener_es/test.json")

# %%
json_eda(df_es_train)
# Out:
# n sentances: 1252
# n holders: 176
# n targets: 2748
# n polarity: 3042
# n expression: 3042
#
# Implicit percentages in the dataset:
# percent implicit holder: 0.9421433267587114,
# percent implicit target: 0.09664694280078895,
# percent implicit holder implicit target: 0.08481262327416174,
# percent implicit expression: 0.0
#
# Implicit target exclusive: 0.011834319526627219
#
# Implicit holder exclusive: 0.8573307034845496
# H-A-O: 0.04602235371466141
# H-IA-IO: 0.0
# H-A-IO: 0.0
# H-IA-O: 0.0
# IH-A-O: 0.8573307034845496
# IH-A-IO: 0.0
# IH-IA-O: 0.08481262327416174
# Intensity   Standard     Strong         All
# Polarity
# Negative   16.074951   2.662722   18.737673
# Positive   51.314924  29.947403   81.262327
# All        67.389875  32.610125  100.000000
# The total count of sentiments with multiple opinions is: 752
# The percent of sentiments with multiple opinions is: 0.24720578566732412

# %%
json_eda(df_en_dev)
# Out:
# n sentances: 198
# n holders: 49
# n targets: 371
# n polarity: 400
# n expression: 400
#
# Implicit percentages in the dataset:
# percent implicit holder: 0.8775,
# percent implicit target: 0.0725,
# percent implicit holder implicit target: 0.0525,
# percent implicit expression: 0.0
#
# Implicit target exclusive: 0.02
#
# Implicit holder exclusive: 0.825
# H-A-O: 0.1025
# H-IA-IO: 0.0
# H-A-IO: 0.0
# H-IA-O: 0.0
# IH-A-O: 0.825
# IH-A-IO: 0.0
# IH-IA-O: 0.0525
# Intensity  Standard  Strong    All
# Polarity
# Negative      24.75    4.25   29.0
# Positive      42.50   28.50   71.0
# All           67.25   32.75  100.0
# The total count of sentiments with multiple opinions is: 115
# The percent of sentiments with multiple opinions is: 0.2875

# %%
json_eda(df_es_dev)
# Out:
# n sentances: 174
# n holders: 23
# n targets: 363
# n polarity: 387
# n expression: 387
#
# Implicit percentages in the dataset:
# percent implicit holder: 0.9405684754521964,
# percent implicit target: 0.06201550387596899,
# percent implicit holder implicit target: 0.06201550387596899,
# percent implicit expression: 0.0
#
# Implicit target exclusive: 0.0
#
# Implicit holder exclusive: 0.8785529715762274
# H-A-O: 0.059431524547803614
# H-IA-IO: 0.0
# H-A-IO: 0.0
# H-IA-O: 0.0
# IH-A-O: 0.8785529715762274
# IH-A-IO: 0.0
# IH-IA-O: 0.06201550387596899
# Intensity   Standard     Strong         All
# Polarity
# Negative   16.020672   2.067183   18.087855
# Positive   52.713178  29.198966   81.912145
# All        68.733850  31.266150  100.000000
# The total count of sentiments with multiple opinions is: 97
# The percent of sentiments with multiple opinions is: 0.25064599483204136

# %% [markdown]
# # Fine Grain F1 scores

# %%
from nltk.tokenize.simple import SpaceTokenizer
st = SpaceTokenizer()

DATA_DIR = './data'
id2sentiment = {3: 'Negative', 4: 'Neutral', 5: 'Positive'}


class SemEvalEvaluator:

    def __init__(self, predicted_tuples, dataset_name, mode="manual"):

        self.mode = mode

        if mode == "valid":
            gold_path = DATA_DIR / dataset_name / 'test.json'
            self.sent_ids, self.golden_triplets, self.golden_quadtuples = self.load_gold_from_file(gold_path)
            #self.predicted_triplets, self.predicted_quadtuples = self.convert_to_submission_tuple_format(predicted_tuples)
            self.predicted_triplets, self.predicted_quadtuples = self.convert_to_submission_tuple_format_V2(predicted_tuples)
        
        elif mode == "manual":
            gold_path = dataset_name
            pred_path = predicted_tuples
            self.sent_ids, self.golden_quadtuples = self.load_gold_from_file(gold_path)
            self.sent_ids, self.predicted_quadtuples = self.load_preds_from_file(pred_path)
            #self.predicted_triplets, self.predicted_quadtuples = self.convert_to_submission_tuple_format(predicted_tuples)
            # self.predicted_triplets, self.predicted_quadtuples = self.convert_to_submission_tuple_format_V2(predicted_tuples)


    def convert_opinion_to_quadtuples(self, sentence):
        text = sentence["text"]
        opinions = sentence["opinions"]
        opinion_tuples = []
        token_offsets = list(st.span_tokenize(text))
        #
        if len(opinions) > 0:
            for opinion in opinions:
                holder_char_idxs = opinion["Source"][1]
                target_char_idxs = opinion["Target"][1]
                exp_char_idxs = opinion["Polar_expression"][1]
                polarity = opinion["Polarity"]
                #
                holder = self.convert_char_offsets_to_token_idxs(holder_char_idxs, token_offsets)
                target = self.convert_char_offsets_to_token_idxs(target_char_idxs, token_offsets)
                exp = self.convert_char_offsets_to_token_idxs(exp_char_idxs, token_offsets)
                opinion_tuples.append((holder, target, exp, polarity))
        return opinion_tuples

    def convert_char_offsets_to_token_idxs(self, char_offsets, token_offsets):
        """
        char_offsets: list of str
        token_offsets: list of tuples

        >>> text = "I think the new uni ( ) is a great idea"
        >>> char_offsets = ["8:19"]
        >>> token_offsets =
        [(0,1), (2,7), (8,11), (12,15), (16,19), (20,21), (22,23), (24,26), (27,28), (29,34), (35,39)]

        >>> convert_char_offsets_to_token_idxs(char_offsets, token_offsets)
        >>> (2,3,4)
        """
        token_idxs = []
        #
        for char_offset in char_offsets:
            bidx, eidx = char_offset.split(":")
            bidx, eidx = int(bidx), int(eidx)
            intoken = False
            for i, (b, e) in enumerate(token_offsets):
                if b == bidx:
                    intoken = True
                if intoken:
                    token_idxs.append(i)
                if e == eidx:
                    intoken = False
        return set(token_idxs)

    def load_gold_from_file(self, gold_path):

        with open(gold_path) as infile:
            gold = json.load(infile)

        sent_ids = [s["sent_id"] for s in gold] # It is orderly

        if self.mode=='valid' or self.mode=='test' or self.mode=='manual':
        
            golden_quadtuples = dict([(s["sent_id"], self.convert_opinion_to_quadtuples(s)) for s in gold])

            return sent_ids, golden_quadtuples

        elif self.mode=='predict':

            return sent_ids
    
    def load_preds_from_file(self, pred_path): # DL

        with open(pred_path) as infile:
            pred = json.load(infile)

        sent_ids = [s["sent_id"] for s in pred] # It is orderly

        if self.mode=='valid' or self.mode=='test' or self.mode=='manual':
        
            pred_quadtuples = dict([(s["sent_id"], self.convert_opinion_to_quadtuples(s)) for s in pred])

            return sent_ids, pred_quadtuples

        elif self.mode=='predict':

            return sent_ids


    def convert_to_submission_tuple_format_V2(self, tuples): #JR

        assert len(self.sent_ids) == len(tuples)

        all_converted_triplets = {}
        all_converted_quadtuples = {}

        for sent_id, i in zip(self.sent_ids, tuples):

            converted_triplets = []
            converted_quadtuples = []

            for tuple in i:
                holder_start_idx, holder_end_idx = tuple[0], tuple[1]
                aspect_start_idx, aspect_end_idx = tuple[2], tuple[3]
                opinion_start_idx, opinion_end_idx  = tuple[4], tuple[5]
                
                holder_range_set = set(range(holder_start_idx-1, holder_end_idx)) if set(range(holder_start_idx-1, holder_end_idx)) != set([-1]) else set()
                aspect_range_set = set(range(aspect_start_idx-1, aspect_end_idx)) if set(range(aspect_start_idx-1, aspect_end_idx)) != set([-1]) else set()
                opinion_range_set = set(range(opinion_start_idx-1, opinion_end_idx)) if set(range(opinion_start_idx-1, opinion_end_idx)) != set([-1]) else set()
            
                converted_triplets.append((aspect_range_set, opinion_range_set, id2sentiment[tuple[6]]))
                converted_quadtuples.append((holder_range_set, aspect_range_set, opinion_range_set, id2sentiment[tuple[6]]))

            all_converted_triplets[sent_id] = converted_triplets
            all_converted_quadtuples[sent_id] = converted_quadtuples

        return all_converted_triplets, all_converted_quadtuples


    def sent_quadtuples_in_list(self, sent_tuple1, list_of_sent_tuples, keep_polarity=True):
        holder1, target1, exp1, pol1 = sent_tuple1
        if len(holder1) == 0:
            holder1 = frozenset(["_"])
        if len(target1) == 0:
            target1 = frozenset(["_"])
        for holder2, target2, exp2, pol2 in list_of_sent_tuples:
            if len(holder2) == 0:
                holder2 = frozenset(["_"])
            if len(target2) == 0:
                target2 = frozenset(["_"])
            if (
                len(holder1.intersection(holder2)) > 0
                and len(target1.intersection(target2)) > 0
                and len(exp1.intersection(exp2)) > 0
            ):
                if keep_polarity:
                    if pol1 == pol2:
                        return True
                else:
                    return True
        return False

    def quadtuple_weighted_score(self, sent_tuple1, list_of_sent_tuples):
        best_overlap = 0
        holder1, target1, exp1, pol1 = sent_tuple1
        if len(holder1) == 0:
            holder1 = frozenset(["_"])
        if len(target1) == 0:
            target1 = frozenset(["_"])
        for holder2, target2, exp2, pol2 in list_of_sent_tuples:
            if len(holder2) == 0:
                holder2 = frozenset(["_"])
            if len(target2) == 0:
                target2 = frozenset(["_"])
            if (
                len(holder2.intersection(holder1)) > 0
                and len(target2.intersection(target1)) > 0
                and len(exp2.intersection(exp1)) > 0
            ):
                holder_overlap = len(holder2.intersection(holder1)) / len(holder1)
                target_overlap = len(target2.intersection(target1)) / len(target1)
                exp_overlap = len(exp2.intersection(exp1)) / len(exp1)
                overlap = (holder_overlap + target_overlap + exp_overlap) / 3
                if overlap > best_overlap:
                    best_overlap = overlap
        return best_overlap

    def quadtuple_precision(self, gold, pred, keep_polarity=True, weighted=True):
        """
        Weighted true positives / (true positives + false positives)
        """
        weighted_tp = []
        tp = []
        fp = []
        #
        for sent_idx in pred.keys():
            
            atomic_tp = [] # DL
            atomic_fp = [] # Dl

            ptuples = pred[sent_idx]
            gtuples = gold[sent_idx]
            for stuple in ptuples:
                if self.sent_quadtuples_in_list(stuple, gtuples, keep_polarity):
                    if weighted:
                        weighted_tp.append(self.quadtuple_weighted_score(stuple, gtuples))
                        # print('added weighted_tp') # DL
                        tp.append(1)
                        atomic_tp.append(1) # DL

                    else:
                        weighted_tp.append(1)
                        tp.append(1)
                        atomic_fp.append(1) # DL
                else:
                    fp.append(1)
                    atomic_fp.append(1) # DL
                
                print(f'sent_idx: {sent_idx}, {sum(weighted_tp) / (sum(atomic_tp) + sum(atomic_fp) + 0.0000000000000001)}' ) # DL

        return sum(weighted_tp) / (sum(tp) + sum(fp) + 0.0000000000000001)

    def quadtuple_recall(self, gold, pred, keep_polarity=True, weighted=True):
        """
        Weighted true positives / (true positives + false negatives)
        """
        weighted_tp = []
        tp = []
        fn = []
        #
        assert len(gold) == len(pred)
        #
        for sent_idx in pred.keys():
            
            atomic_weighted_tp = [] # DL
            atomic_tp = [] # DL
            atomic_fn = [] # Dl


            ptuples = pred[sent_idx]
            gtuples = gold[sent_idx]
            for stuple in gtuples:
                if self.sent_quadtuples_in_list(stuple, ptuples, keep_polarity):
                    if weighted:
                        weighted_tp.append(self.quadtuple_weighted_score(stuple, ptuples))
                        tp.append(1)
                        atomic_tp.append(1) # DL
                    else:
                        weighted_tp.append(1)
                        tp.append(1)
                        atomic_tp.append(1) # DL
                else:
                    fn.append(1)
                    atomic_fn.append(1)

                print(f'sent_idx: {sent_idx}, {sum(weighted_tp) / (sum(atomic_tp) + sum(atomic_fp) + 0.0000000000000001)}' ) # DL

        return sum(weighted_tp) / (sum(tp) + sum(fn) + 0.0000000000000001)

    def get_all_quadtuple_metrics(self, keep_polarity=True, weighted=True):

        prec = self.quadtuple_precision(self.golden_quadtuples, self.predicted_quadtuples, keep_polarity, weighted)
        rec = self.quadtuple_recall(self.golden_quadtuples, self.predicted_quadtuples, keep_polarity, weighted)

        return prec, rec, 2 * (prec * rec) / (prec + rec + 0.00000000000000001)

# %%
semeval_evaluator = SemEvalEvaluator(predicted_tuples="./en_all-roberta-large-v1_pred.json", dataset_name="./data/opener_en/test.json", mode="manual")
_precision, _recall, _f1 = semeval_evaluator.get_all_quadtuple_metrics()
print(_precision, _recall, _f1)
# Out:
# added weighted_tp
# sent_idx: opener_en/kaf/hotel/english00148_ddb06f1e4ab012d85f9120c394168c48-8, 1e+16
# added weighted_tp
# sent_idx: opener_en/kaf/hotel/english00028_2a1e03a3e5d6afe2c5024926cb7ff9ab-2, 1e+16
# added weighted_tp
# sent_idx: opener_en/kaf/hotel/english00028_2a1e03a3e5d6afe2c5024926cb7ff9ab-3, 1e+16
# added weighted_tp
# sent_idx: opener_en/kaf/hotel/english00028_2a1e03a3e5d6afe2c5024926cb7ff9ab-4, 1e+16
# added weighted_tp
# sent_idx: opener_en/kaf/hotel/english
 0.5
# added weighted_tp
# sent_idx: opener_en/kaf/hotel/english00120_afc3a95e54291de7a4e3f3d692cec8ee-3, 1e+16
# added weighted_tp
# sent_idx: opener_en/kaf/hotel/english00120_afc3a95e54291de7a4e3f3d692cec8ee-3, 2e+16
# added weighted_tp
# sent_idx: opener_en/kaf/hotel/english00120_afc3a95e54291de7a4e3f3d692cec8ee-3, 3e+16
# sent_idx: opener_en/kaf/hotel/english00120_afc3a95e54291de7a4e3f3d692cec8ee-3, 1.5
# added weighted_tp
# sent_idx: opener_en/kaf/hotel/english00120_afc3a95e54291de7a4e3f3d692cec8ee-3, 2.0
# sent_idx: opener_en/kaf/hotel/english00078_726dab247b93f8e93eeeabc72f74d655-1, 0.0
# sent_idx: opener_en/kaf/hotel/english00078_726dab247b93f8e93eeeabc72f74d655-1, 0.0
# added weighted_tp
# sent_idx: opener_en/kaf/hotel/english00078_726dab247b93f8e93eeeabc72f74d655-2, 1e+16
# added weighted_tp
# sent_idx: opener_en/kaf/hotel/english00078_726dab247b93f8e93eeeabc72f74d655-3, 1e+16
# sent_idx: opener_en/kaf/hotel/english00078_726dab247b93f8e93eeeabc72f74d655-5, 0.0
# sent_idx: opener_en/kaf/hotel/english00078_726dab247b93f8e93eeeabc72f74d655-5, 0.0
# sent_idx: opener_en/kaf/hotel/english00078_726dab247b93f8e93eeeabc72f74d655-6, 0.0
# added weighted_tp
# sent_idx: opener_en/kaf/hotel/english00113_8161bacaf54503f451c7246b073003a5-1, 1e+16
# added weighted_tp
# sent_idx: opener_en/kaf/hotel/english00113_8161bacaf54503f451c7246b073003a5-2, 1e+16
# added weighted_tp
# sent_idx: opener_en/kaf/hotel/english00113_8161bacaf54503f451c7246b073003a5-2, 2e+16
# added weighted_tp
# sent_idx: opener_en/kaf/hotel/english00113_8161bacaf54503f451c7246b073003a5-3, 1e+16
# added weighted_tp
# sent_idx: opener_en/kaf/hotel/english00113_8161bacaf54503f451c7246b073003a5-3, 2e+16
# added weighted_tp
# sent_idx: opener_en/kaf/hotel/english00113_8161bacaf54503f451c7246b073003a5-4, 1e+16
# added weighted_tp
# sent_idx: opener_en/kaf/hotel/english00113_8161bacaf54503f451c7246b073003a5-4, 2e+16
# added weighted_tp
# sent_idx: opener_en/kaf/hotel/english00113_8161bacaf54503f451c7246b073003a5-4, 3e+16
# added weighted_tp
# sent_idx: opener_en/kaf/hotel/english00113_8161bacaf54503f451c7246b073003a5-5, 1e+16
# added weighted_tp
# sent_idx: opener_en/kaf/hotel/english00113_8161bacaf54503f451c7246b073003a5-5, 2e+16
# added weighted_tp
# sent_idx: opener_en/kaf/hotel/english00113_8161bacaf54503f451c7246b073003a5-5, 3e+16
# added weighted_tp
# sent_idx: opener_en/kaf/hotel/english00113_8161bacaf54503f451c7246b073003a5-5, 4e+16
# added weighted_tp
# sent_idx: opener_en/kaf/hotel/english00113_8161bacaf54503f451c7246b073003a5-6, 1e+16
# added weighted_tp
# sent_idx: opener_en/kaf/hotel/english00113_8161bacaf54503f451c7246b073003a5-6, 2e+16
# added weighted_tp
# sent_idx: opener_en/kaf/hotel/english00113_8161bacaf54503f451c7246b073003a5-8, 1e+16
# sent_idx: opener_en/kaf/hotel/english00113_8161bacaf54503f451c7246b073003a5-8, 0.5
# added weighted_tp
# sent_idx: opener_en/kaf/hotel/english00113_8161bacaf54503f451c7246b073003a5-9, 1e+16
# added weighted_tp
# sent_idx: opener_en/kaf/hotel/english00113_8161bacaf54503f451c7246b073003a5-9, 2e+16
# added weighted_tp
# sent_idx: opener_en/kaf/hotel/english00113_8161bacaf54503f451c7246b073003a5-9, 3e+16
# 0.6820724980299452 0.6370001835030743 0.6587662870896918

# %%
df_en_roberta_largev1
# Out:
#                                                                                                                          text  \
# 0                                                                                 Thank you for such a wonderful experience .
# 1                                                                                              Hotel was under construction .
# 2                                                                                                    Carpets where very old .
# 3                                                                              Staircase only on the outside and not heated .
# 4                                                                              Staircase only on the outside and not heated .
# ..                                                                                                                        ...
# 841  Front desk wasn 't the best , quite slow for passport registration and clerk insisted that we pay up for a better room .
# 842  Front desk wasn 't the best , quite slow for passport registration and clerk insisted that we pay up for a better room .
# 843                                                                 In · room breakfast was tasty and quite large , awesome .
# 844                                                                 In · room breakfast was tasty and quite large , awesome .
# 845                                                                 In · room breakfast was tasty and quite large , awesome .
#
#                                                                  sent_id  \
# 0    opener_en/kaf/hotel/english00148_ddb06f1e4ab012d85f9120c394168c48-8
# 1    opener_en/kaf/hotel/english00028_2a1e03a3e5d6afe2c5024926cb7ff9ab-2
# 2    opener_en/kaf/hotel/english00028_2a1e03a3e5d6afe2c5024926cb7ff9ab-3
# 3    opener_en/kaf/hotel/english00028_2a1e03a3e5d6afe2c5024926cb7ff9ab-4
# 4    opener_en/kaf/hotel/english00028_2a1e03a3e5d6afe2c5024926cb7ff9ab-4
# ..                                                                   ...
# 841  opener_en/kaf/hotel/english00113_8161bacaf54503f451c7246b073003a5-8
# 842  opener_en/kaf/hotel/english00113_8161bacaf54503f451c7246b073003a5-8
# 843  opener_en/kaf/hotel/english00113_8161bacaf54503f451c7246b073003a5-9
# 844  opener_en/kaf/hotel/english00113_8161bacaf54503f451c7246b073003a5-9
# 845  opener_en/kaf/hotel/english00113_8161bacaf54503f451c7246b073003a5-9
#
#        Source Source_string Source_index                      Target  \
# 0    [[], []]            []           []     [[experience], [31:41]]
# 1    [[], []]            []           []            [[Hotel], [0:5]]
# 2    [[], []]            []           []          [[Carpets], [0:7]]
# 3    [[], []]            []           []        [[Staircase], [0:9]]
# 4    [[], []]            []           []        [[Staircase], [0:9]]
# ..        ...           ...          ...                         ...
# 841  [[], []]            []           []      [[Front desk], [0:10]]
# 842  [[], []]            []           []  [[better room], [107:118]]
# 843  [[], []]            []           []  [[room breakfast], [5:19]]
# 844  [[], []]            []           []  [[room breakfast], [5:19]]
# 845  [[], []]            []           []  [[room breakfast], [5:19]]
#
#         Target_string Target_index                  Polar_expression  \
# 0        [experience]      [31:41]            [[wonderful], [21:30]]
# 1             [Hotel]        [0:5]   [[under construction], [10:28]]
# 2           [Carpets]        [0:7]             [[very old], [14:22]]
# 3         [Staircase]        [0:9]  [[only on the outside], [10:29]]
# 4         [Staircase]        [0:9]           [[not heated], [34:44]]
# ..                ...          ...                               ...
# 841      [Front desk]       [0:10]     [[wasn 't the best], [11:27]]
# 842     [better room]    [107:118]                  [[pay], [94:97]]
# 843  [room breakfast]       [5:19]                [[tasty], [24:29]]
# 844  [room breakfast]       [5:19]          [[quite large], [34:45]]
# 845  [room breakfast]       [5:19]              [[awesome], [48:55]]
#
#     Polar_expression_string  ... Implicit_target_exclusive  \
# 0               [wonderful]  ...                     False
# 1      [under construction]  ...                     False
# 2                [very old]  ...                     False
# 3     [only on the outside]  ...                     False
# 4              [not heated]  ...                     False
# ..                      ...  ...                       ...
# 841      [wasn 't the best]  ...                     False
# 842                   [pay]  ...                     False
# 843                 [tasty]  ...                     False
# 844           [quite large]  ...                     False
# 845               [awesome]  ...                     False
#
#     Implicit_holder_exclusive  H-A-O  H-IA-IO  H-A-IO  H-IA-O  IH-A-O  \
# 0                        True      0    False   False   False    True
# 1                        True      0    False   False   False    True
# 2                        True      0    False   False   False    True
# 3                        True      0    False   False   False    True
# 4                        True      0    False   False   False    True
# ..                        ...    ...      ...     ...     ...     ...
# 841                      True      0    False   False   False    True
# 842                      True      0    False   False   False    True
# 843                      True      0    False   False   False    True
# 844                      True      0    False   False   False    True
# 845                      True      0    False   False   False    True
#
#      IH-A-IO  IH-IA-O  IH-IA-IO
# 0      False    False     False
# 1      False    False     False
# 2      False    False     False
# 3      False    False     False
# 4      False    False     False
# ..       ...      ...       ...
# 841    False    False     False
# 842    False    False     False
# 843    False    False     False
# 844    False    False     False
# 845    False    False     False
#
# [846 rows x 27 columns]

# %%
df_opener_en_test
# Out:
#                                                                                                                          text  \
# 0                                                                                     They were there just to keep us happy .
# 1                                                   A wonderful place to go and we are planning to return as soon as we can .
# 2                                                   A wonderful place to go and we are planning to return as soon as we can .
# 3                                                                                 Thank you for such a wonderful experience .
# 4                                                                                              Hotel was under construction .
# ..                                                                                                                        ...
# 860  Front desk wasn 't the best , quite slow for passport registration and clerk insisted that we pay up for a better room .
# 861  Front desk wasn 't the best , quite slow for passport registration and clerk insisted that we pay up for a better room .
# 862                                                                 In · room breakfast was tasty and quite large , awesome .
# 863                                                                 In · room breakfast was tasty and quite large , awesome .
# 864                                                                 In · room breakfast was tasty and quite large , awesome .
#
#                                                                  sent_id  \
# 0    opener_en/kaf/hotel/english00148_ddb06f1e4ab012d85f9120c394168c48-6
# 1    opener_en/kaf/hotel/english00148_ddb06f1e4ab012d85f9120c394168c48-7
# 2    opener_en/kaf/hotel/english00148_ddb06f1e4ab012d85f9120c394168c48-7
# 3    opener_en/kaf/hotel/english00148_ddb06f1e4ab012d85f9120c394168c48-8
# 4    opener_en/kaf/hotel/english00028_2a1e03a3e5d6afe2c5024926cb7ff9ab-2
# ..                                                                   ...
# 860  opener_en/kaf/hotel/english00113_8161bacaf54503f451c7246b073003a5-8
# 861  opener_en/kaf/hotel/english00113_8161bacaf54503f451c7246b073003a5-8
# 862  opener_en/kaf/hotel/english00113_8161bacaf54503f451c7246b073003a5-9
# 863  opener_en/kaf/hotel/english00113_8161bacaf54503f451c7246b073003a5-9
# 864  opener_en/kaf/hotel/english00113_8161bacaf54503f451c7246b073003a5-9
#
#               Source Source_string Source_index                   Target  \
# 0    [[us], [29:31]]          [us]      [29:31]          [[They], [0:4]]
# 1           [[], []]            []           []       [[place], [12:17]]
# 2    [[we], [28:30]]          [we]      [28:30]                 [[], []]
# 3           [[], []]            []           []  [[experience], [31:41]]
# 4           [[], []]            []           []         [[Hotel], [0:5]]
# ..               ...           ...          ...                      ...
# 860         [[], []]            []           []   [[Front desk], [0:10]]
# 861         [[], []]            []           []   [[Front desk], [0:10]]
# 862         [[], []]            []           []   [[breakfast], [10:19]]
# 863         [[], []]            []           []   [[breakfast], [10:19]]
# 864         [[], []]            []           []   [[breakfast], [10:19]]
#
#     Target_string Target_index                    Polar_expression  \
# 0          [They]        [0:4]  [[to keep, happy], [21:28, 32:37]]
# 1         [place]      [12:17]               [[wonderful], [2:11]]
# 2              []           []     [[planning to return], [35:53]]
# 3    [experience]      [31:41]              [[wonderful], [21:30]]
# 4         [Hotel]        [0:5]     [[under construction], [10:28]]
# ..            ...          ...                                 ...
# 860  [Front desk]       [0:10]             [[quite slow], [30:40]]
# 861  [Front desk]       [0:10]       [[wasn 't the best], [11:27]]
# 862   [breakfast]      [10:19]            [[quite large], [34:45]]
# 863   [breakfast]      [10:19]                  [[tasty], [24:29]]
# 864   [breakfast]      [10:19]                [[awesome], [48:55]]
#
#     Polar_expression_string  ... Implicit_target_exclusive  \
# 0          [to keep, happy]  ...                     False
# 1               [wonderful]  ...                     False
# 2      [planning to return]  ...                      True
# 3               [wonderful]  ...                     False
# 4      [under construction]  ...                     False
# ..                      ...  ...                       ...
# 860            [quite slow]  ...                     False
# 861      [wasn 't the best]  ...                     False
# 862           [quite large]  ...                     False
# 863                 [tasty]  ...                     False
# 864               [awesome]  ...                     False
#
#     Implicit_holder_exclusive H-A-O  H-IA-IO  H-A-IO  H-IA-O  IH-A-O  IH-A-IO  \
# 0                       False     1    False   False   False   False    False
# 1                        True     0    False   False   False    True    False
# 2                       False     0    False   False    True   False    False
# 3                        True     0    False   False   False    True    False
# 4                        True     0    False   False   False    True    False
# ..                        ...   ...      ...     ...     ...     ...      ...
# 860                      True     0    False   False   False    True    False
# 861                      True     0    False   False   False    True    False
# 862                      True     0    False   False   False    True    False
# 863                      True     0    False   False   False    True    False
# 864                      True     0    False   False   False    True    False
#
#      IH-IA-O  IH-IA-IO
# 0      False     False
# 1      False     False
# 2      False     False
# 3      False     False
# 4      False     False
# ..       ...       ...
# 860    False     False
# 861    False     False
# 862    False     False
# 863    False     False
# 864    False     False
#
# [865 rows x 27 columns]
